# %%
"""
set up the beginning part of the program so that it runs off a single command and returns a df
"""

# %%
from selenium import webdriver

from selenium.webdriver.common.keys import Keys

from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions

from bs4 import BeautifulSoup
from collections import defaultdict

import time
import os

import numpy as np
import pandas as pd

# %%
def set_ff_preferences():
    profile = webdriver.FirefoxProfile()
    profile.set_preference('browser.download.folderList', 2) # custom location
    profile.set_preference('browser.download.dir', (os.getcwd()+'/data/'))
    profile.set_preference('browser.download.manager.showWhenStarting', False)
    profile.set_preference('browser.helperApps.neverAsk.saveToDisk', "application/csv, text/csv")
    return profile

def create_empty_ff_driver():
    profile = set_ff_preferences()
    a_driver = webdriver.Firefox(firefox_profile=profile)
    return a_driver

def create_driver_opening_url():
    a_driver = create_empty_ff_driver()
    return a_driver

def soup_from_driver(a_driver):
    soup = BeautifulSoup(a_driver.page_source, 'html.parser')
    return soup

def clean_from_text(text):
#     cleaned_text = text.replace(",","").strip()
    cleaned_text = text.strip()
    return cleaned_text

# %%
rf_search = 'https://www.redfin.com/city/16164/FL/St-Petersburg/filter/property-type=multifamily,max-price=700k,include=forsale+mlsfsbo+construction+fsbo+foreclosed+sold-3mo,viewport=27.91387:27.72085:-82.54595:-82.86657,no-outline'

def init_driver(url):
    a_driver = create_driver_opening_url()
    a_driver.get(url)
    return a_driver
    
def dl_data(a_driver):
    dl_button = WebDriverWait(a_driver, 10).until(
    expected_conditions.presence_of_element_located(
        (By.XPATH, """//*[@id="download-and-save"]""")))
    dl_button.click()
    
def get_csv(url):
    a_driver = init_driver(url)
    dl_data(a_driver)
    a_driver.close()

# %%
get_csv(rf_search)

# %%
os.listdir('data')
# Out:
# ['redfin_2021-06-09-07-35-27.csv',
#  'redfin_2021-06-22-09-35-26.csv',
#  'redfin_2021-06-19-18-35-53.csv',
#  'redfin_2021-06-22-18-48-30.csv',
#  'redfin_2021-06-18-11-37-46.csv',
#  'redfin_2021-05-28-10-35-52.csv',
#  'redfin_2021-06-22-18-25-29.csv',
#  'redfin_2021-06-22-16-16-17(1).csv',
#  'redfin_2021-06-22-17-11-32.csv',
#  'redfin_2021-06-22-16-49-45.csv',
#  'redfin_2021-06-15-12-38-40.csv',
#  'redfin_2021-06-22-16-16-17.csv',
#  'redfin_2021-05-27-14-11-12.csv',
#  'redfin_2021-06-11-09-12-35.csv',
#  'redfin_2021-06-22-09-55-32.csv',
#  'redfin_2021-05-26-04-31-10.csv',
#  'redfin_2021-06-21-10-49-01.csv',
#  'redfin_2021-06-21-10-49-01(1).csv',
#  'redfin_2021-06-22-16-16-17(2).csv',
#  'redfin_2021-06-18-09-56-09.csv',
#  '.~lock.redfin_2021-05-25-19-10-03.csv#',
#  'redfin_2021-06-21-07-12-51.csv']

# %%
os.listdir('data')[0]
# Out:
# 'redfin_2021-06-09-07-35-27.csv'

# %%
file_str = 'data/'+str(os.listdir('data')[0])
file_str
# Out:
# 'data/redfin_2021-06-09-07-35-27.csv'

# %%
df=pd.read_csv(file_str)

# %%
df
# Out:
#       SALE TYPE  SOLD DATE            PROPERTY TYPE  \
# 0   MLS Listing        NaN  Multi-Family (2-4 Unit)
# 1   MLS Listing        NaN  Multi-Family (2-4 Unit)
# 2   MLS Listing        NaN  Multi-Family (2-4 Unit)
# 3   MLS Listing        NaN  Multi-Family (2-4 Unit)
# 4   MLS Listing        NaN  Multi-Family (2-4 Unit)
# 5   MLS Listing        NaN  Multi-Family (2-4 Unit)
# 6   MLS Listing        NaN  Multi-Family (2-4 Unit)
# 7   MLS Listing        NaN  Multi-Family (2-4 Unit)
# 8   MLS Listing        NaN  Multi-Family (2-4 Unit)
# 9   MLS Listing        NaN  Multi-Family (2-4 Unit)
# 10  MLS Listing        NaN  Multi-Family (2-4 Unit)
# 11  MLS Listing        NaN  Multi-Family (2-4 Unit)
# 12  MLS Listing        NaN   Multi-Family (5+ Unit)
# 13  MLS Listing        NaN  Multi-Family (2-4 Unit)
# 14  MLS Listing        NaN  Multi-Family (2-4 Unit)
# 15  MLS Listing        NaN  Multi-Family (2-4 Unit)
# 16  MLS Listing        NaN  Multi-Family (2-4 Unit)
# 17  MLS Listing        NaN  Multi-Family (2-4 Unit)
# 18  MLS Listing        NaN  Multi-Family (2-4 Unit)
# 19  MLS Listing        NaN  Multi-Family (2-4 Unit)
# 20  MLS Listing        NaN  Multi-Family (2-4 Unit)
# 21  MLS Listing        NaN  Multi-Family (2-4 Unit)
# 22  MLS Listing        NaN   Multi-Family (5+ Unit)
#
#                            ADDRESS              CITY STATE OR PROVINCE  \
# 0                  3109 54th Ave N     ST PETERSBURG                FL
# 1                     715 8th St N     ST PETERSBURG                FL
# 2                   2624 12th St N     ST PETERSBURG                FL
# 3                  5549 59th Way N     ST PETERSBURG                FL
# 4                  5565 59th Way N     ST PETERSBURG                FL
# 5   1860 Massachusetts Ave NE #321     ST PETERSBURG                FL
# 6                  1145 16th Ave S     ST PETERSBURG                FL
# 7            2046 Queensboro Ave S     ST PETERSBURG                FL
# 8            4-PLEX   324 7th St S     ST PETERSBURG                FL
# 9                   3434 3rd Ave S    ST. PETERSBURG                FL
# 10                 144 174th Ave E  REDINGTON SHORES                FL
# 11                   7301 7th St N     ST PETERSBURG                FL
# 12                  707 20th Ave S     ST PETERSBURG                FL
# 13                 10598 106th Ave             LARGO                FL
# 14                  719 20th Ave S     ST PETERSBURG                FL
# 15                  618 17th Ave S     ST PETERSBURG                FL
# 16                 6605 48th Ave N     ST PETERSBURG                FL
# 17                  1761 19th St S     ST PETERSBURG                FL
# 18                 1320 18th Ave S     ST PETERSBURG                FL
# 19                  659 26th Ave S     ST PETERSBURG                FL
# 20               2151 Oakley Ave S     ST PETERSBURG                FL
# 21                  4010 32nd St N     ST PETERSBURG                FL
# 22             379 47th Ave N #106     ST PETERSBURG                FL
#
#     ZIP OR POSTAL CODE   PRICE  BEDS  BATHS  ...  STATUS  \
# 0                33714  225000   4.0    3.0  ...  Active
# 1                33701  675000   6.0    5.0  ...  Active
# 2                33704  475000   NaN    NaN  ...  Active
# 3                33709  295000   4.0    2.0  ...  Active
# 4                33709  315000   4.0    2.0  ...  Active
# 5                33703  137000   NaN    NaN  ...  Active
# 6                33705  350000   7.0    3.0  ...  Active
# 7                33712  369000   6.0    3.0  ...  Active
# 8                33701  645000   4.0    4.0  ...  Active
# 9                33711  279000   5.0    2.0  ...  Active
# 10               33708  595000   2.0    2.0  ...  Active
# 11               33702  500000   5.0    4.0  ...  Active
# 12               33705  525000   7.0    6.0  ...  Active
# 13               33773  495000   4.0    4.0  ...  Active
# 14               33705  264975   NaN    NaN  ...  Active
# 15               33701  308900   4.0    3.0  ...  Active
# 16               33709  399900   6.0    2.0  ...  Active
# 17               33712  460000   4.0    4.0  ...  Active
# 18               33705  349999   3.0    2.0  ...  Active
# 19               33705  195000   4.0    2.0  ...  Active
# 20               33712  265000   5.0    2.0  ...  Active
# 21               33714  324900   4.0    2.0  ...  Active
# 22               33703  265000   3.0    3.0  ...  Active
#
#     NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# 5                          NaN                       NaN
# 6                          NaN                       NaN
# 7                          NaN                       NaN
# 8                          NaN                       NaN
# 9                          NaN                       NaN
# 10                         NaN                       NaN
# 11                         NaN                       NaN
# 12                         NaN                       NaN
# 13                         NaN                       NaN
# 14                         NaN                       NaN
# 15                         NaN                       NaN
# 16                         NaN                       NaN
# 17                         NaN                       NaN
# 18                         NaN                       NaN
# 19                         NaN                       NaN
# 20                         NaN                       NaN
# 21                         NaN                       NaN
# 22                         NaN                       NaN
#
#     URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 0   http://www.redfin.com/FL/St-Petersburg/3109-54...
# 1   http://www.redfin.com/FL/St-Petersburg/715-8th...
# 2   http://www.redfin.com/FL/St-Petersburg/2624-12...
# 3   http://www.redfin.com/FL/St-Petersburg/5549-59...
# 4   http://www.redfin.com/FL/St-Petersburg/5565-59...
# 5   http://www.redfin.com/FL/St-Petersburg/1860-Ma...
# 6   http://www.redfin.com/FL/St-Petersburg/1145-16...
# 7   http://www.redfin.com/FL/St-Petersburg/2046-Qu...
# 8   http://www.redfin.com/FL/St-Petersburg/324-7th...
# 9   http://www.redfin.com/FL/St-Petersburg/3434-3r...
# 10  http://www.redfin.com/FL/Redington-Shores/144-...
# 11  http://www.redfin.com/FL/St-Petersburg/7301-7t...
# 12  http://www.redfin.com/FL/St-Petersburg/707-20t...
# 13  http://www.redfin.com/FL/Largo/10598-106th-Ave...
# 14  http://www.redfin.com/FL/St-Petersburg/719-20t...
# 15  http://www.redfin.com/FL/St-Petersburg/618-17t...
# 16  http://www.redfin.com/FL/St-Petersburg/6605-48...
# 17  http://www.redfin.com/FL/St-Petersburg/1761-19...
# 18  http://www.redfin.com/FL/St-Petersburg/1320-18...
# 19  http://www.redfin.com/FL/St-Petersburg/659-26t...
# 20  http://www.redfin.com/FL/St-Petersburg/2151-Oa...
# 21  http://www.redfin.com/FL/St-Petersburg/4010-32...
# 22  http://www.redfin.com/FL/St-Petersburg/379-47t...
#
#          SOURCE       MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 0   Stellar MLS   T3311382         N          Y  27.821322 -82.675916
# 1   Stellar MLS   U8126271         N          Y  27.779712 -82.644441
# 2   Stellar MLS   U8126216         N          Y  27.796263 -82.650591
# 3   Stellar MLS   U8126224         N          Y  27.822442 -82.715608
# 4   Stellar MLS   U8126240         N          Y  27.822552 -82.715514
# 5   Stellar MLS   T3311286         N          Y  27.815588 -82.600883
# 6   Stellar MLS   U8125829         N          Y  27.754579 -82.650602
# 7   Stellar MLS   U8125845         N          Y  27.752778 -82.660478
# 8   Stellar MLS   U8121715         N          Y  27.767933 -82.643048
# 9       FORTMLS  221038930         N          Y  27.767955 -82.680345
# 10  Stellar MLS   T3308117         N          Y  27.823048 -82.825878
# 11  Stellar MLS   T3307305         N          Y  27.839167 -82.642587
# 12  Stellar MLS   T3307588         N          Y  27.750612 -82.642841
# 13  Stellar MLS   U8123274         N          Y  27.868775 -82.785597
# 14  Stellar MLS   T3303841         N          Y  27.750553 -82.642985
# 15  Stellar MLS   A4499082         N          Y  27.753243 -82.640895
# 16  Stellar MLS   U8120830         N          Y  27.815735 -82.729669
# 17  Stellar MLS   U8120732         N          Y  27.752889 -82.659083
# 18  Stellar MLS   T3301154         N          Y  27.751770 -82.652718
# 19  Stellar MLS   T3301101         N          Y  27.745237 -82.641951
# 20  Stellar MLS   T3296071         N          Y  27.755537 -82.661906
# 21  Stellar MLS   U8105789         N          Y  27.808801 -82.676758
# 22  Stellar MLS   U8090215         N          Y  27.815320 -82.637559
#
# [23 rows x 27 columns]

# %%
df.rename(columns={"URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)":"URL"},inplace=True)

# %%
def clean_data_list(data_list):
    clean_list = ['Today','Price', 'Date','Public Records','Show Less']
    partial_list = ['Stellar', 'Sold for']
    
    for i in data_list:
        if i in clean_list:
            data_list.remove(i)
    for i in data_list:
        for j in partial_list:
            if j in i:
                data_list.remove(i)
    for i in data_list:
        if i[3:5] == ', ':
            data_list.remove(i)
            
#     for i in data_list:
#         if i in clean_list:
#             data_list.remove(i)
#         elif i[3:5] == ', ':
#             data_list.remove(i)
#         else:
#             for j in partial_list:
#                 if j in i:
#                     data_list.remove(i)
                    
    return data_list

# %%
def df_from_long_list(long_list):
    td_list = []
    for i in range(len(long_list))[::3]:
        try:
            od_list = [long_list[i],long_list[i+1],long_list[i+2]]
            td_list.append(od_list)
        except:
            None
    df = pd.DataFrame(td_list, columns =['Date', 'Event', 'Price'])
    return df

# %%
def clean_price(s):
    if type(s) is str:
        s = s.split()[0]
        clean_list = ['$',',']
        for i in clean_list:
            if i in s:
                s = s.replace(i,'')
        if len(s) == 1:
            return np.nan
    return float(s)

# %%
def click_expand_property_history(a_driver):
    button_xpath = "//*[contains(text(), 'See all property history')]"
    
    expand_button = WebDriverWait(a_driver, 10).until(
        expected_conditions.presence_of_element_located(
        (By.XPATH, button_xpath)))

    expand_button.click()

# %%
def get_raw_property_history_data(a_driver):
    section_id = 'propertyHistory-expandable-segment'

    price_history_table = WebDriverWait(a_driver, 10).until(
        expected_conditions.presence_of_element_located(
            (By.ID, section_id)))
    
    return price_history_table.text.split('\n')

# %%
def clean_df(df):
    df = df[df['Price'] != 'Continue reading']
    df['Price'] = df['Price'].apply(clean_price)
    df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
    return df

# %%
def get_property_history(a_url, a_driver):
    a_driver.get(a_url)
    click_expand_property_history(a_driver)
    raw_data = get_raw_property_history_data(a_driver)
    df = df_from_long_list(clean_data_list(raw_data))
    df = clean_df(df)
    return df

# %%
url1 = 'http://www.redfin.com/FL/St-Petersburg/3109-54th-Ave-N-33714/home/48228075'
url2 = 'http://www.redfin.com/FL/St-Petersburg/715-8th-St-N-33701/home/48053682'
a_driver = create_driver_opening_url()
df1 = get_property_history(url1, a_driver)
df2 = get_property_history(url2, a_driver)
# Out:
# <ipython-input-25-a6ed7604fde6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price'] = df['Price'].apply(clean_price)
# <ipython-input-25-a6ed7604fde6>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# %%
df1
# Out:
#         Date                  Event     Price
# 0 2021-06-22      Relisted (Active)       NaN
# 1 2021-06-14                Pending       NaN
# 2 2021-06-08        Listed (Active)  225000.0
# 3 2020-05-21   Delisted (Withdrawn)       NaN
# 4 2020-05-13        Listed (Active)       NaN
# 5 2018-07-12  Sold (Public Records)  104000.0
# 6 1989-07-01  Sold (Public Records)   28600.0
# 7 1986-07-29  Sold (Public Records)   40000.0

# %%
df2
# Out:
#          Date                  Event     Price
# 0  2021-06-14                Pending       NaN
# 1  2021-06-08        Listed (Active)  675000.0
# 2  2013-05-15  Sold (Public Records)  249000.0
# 3  2013-05-14             Sold (MLS)  249000.0
# 4  2012-01-23                 Listed  249000.0
# 6  2013-05-14             Sold (MLS)  249000.0
# 7  2012-01-23                 Listed  249000.0
# 9  2009-10-12                 Listed       NaN
# 10 2008-06-03                 Listed       NaN
# 11 1998-06-05  Sold (Public Records)   29000.0
# 12 1985-04-01  Sold (Public Records)  102000.0
